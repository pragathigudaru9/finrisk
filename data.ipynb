# %%
from sec_edgar_downloader import Downloader

# Note: sec-edgar-downloader v5.x requires a company name and email address
# to comply with the SEC EDGAR User-Agent requirements.
# Format: Downloader("Company Name", "email@address.com", "download_folder")
dl = Downloader("MyCompanyName", "my.email@domain.com", "data")

dl.get(
    "10-K",
    "MSFT",
    limit=3
)
# Out:
# 3

# %%
companies = [
    "MSFT",
    "AAPL",
    "GOOGL",
    "META",
    "AMZN",
    "TSLA",
    "NVDA",
    "JPM",
    "GS",
    "BAC"
]

# %%
tech = [
    "MSFT",
    "AAPL",
    "GOOGL",
    "META",
    "AMZN",
    "NVDA",
    "ORCL",
    "CRM"
]

finance = [
    "JPM",
    "GS",
    "BAC",
    "MS",
    "BLK"
]

consumer = [
    "WMT",
    "COST",
    "HD",
    "NKE",
    "SBUX"
]

healthcare = [
    "JNJ",
    "PFE",
    "MRK",
    "ABBV"
]

industrial = [
    "BA",
    "CAT",
    "GE",
    "DE"
]

energy = [
    "XOM",
    "CVX",
    "COP"
]

import os

root = "data/sec-edgar-filings"

for company in os.listdir(root):
    print(company)
# Out:
# MSFT

# %%
from sec_edgar_downloader import Downloader

dl = Downloader("data")

for ticker in companies:
    print(f"Downloading {ticker}")
    dl.get(
        "10-K",
        ticker,
        limit=3
    )
